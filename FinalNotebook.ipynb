# %% [markdown]
# <h1>Proyek Analisis Data:</h1>
# <p>Nama: Gilbert Samuel Nicholas Silaban</p>
# <p>Email: gilbert.1801.samuel@gmail.com</p>
# <p>Id Dicoding:</p>

# %% [markdown]
# <h1>Menentukan Pertanyaan Bisnis </h1>
# <p>Pertanyaan 1:Which product has return great income for company? and which product has return low income?</p>
# <p>Pertanyaan 2: Which city has the biggest order in Brazil?</p>
# <p>Pertanyaan 3: Which the most payment type use in payment method and which the lowest payment type in Brazil?</p>

# %%
#Import Library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Gathering Data</h2>

# %%
customer_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\customers_dataset.csv')
order_items_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\order_items_dataset.csv')
order_payments_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\order_payments_dataset.csv')
order_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\orders_dataset.csv')
order_review_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\order_reviews_dataset.csv')
product_category_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\product_category_name_translation.csv')
product_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\products_dataset.csv')
seller_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\sellers_dataset.csv')
geo_df=pd.read_csv(r'C:\Users\USER\Documents\DataScience\Dicoding\Latihan\Project\E-Commerce Public Dataset\geolocation_dataset.csv')

# %% [markdown]
# <h2>Assesing Data</h2>

# %% [markdown]
# Identify Customer dataset, Geolocation Dataset

# %%
customer_df.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Looks this DataFrame is clean, next check the geolocation

# %%
geo_df.head(10)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
# 5                         1012       -23.547762       -46.635361
# 6                         1047       -23.546273       -46.641225
# 7                         1013       -23.546923       -46.634264
# 8                         1029       -23.543769       -46.634278
# 9                         1011       -23.547640       -46.636032
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP
# ...

# %%
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geo_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# Looks this DataFrame clean, lets check the order Dataset

# %% [markdown]
# Checking Order_items,Payment, Reviews, and Main Model

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There was typedata in date as object

# %% [markdown]
# Checking The Payment

# %%
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_payments_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Checking the order dataframe

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
order_df[order_df.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There was Not a Number in date, date type data is Object

# %% [markdown]
# Checking the product dataframe

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# There was incosistent number of each data such as product_id, product_length,product_height, product_width

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_df.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %% [markdown]
# Error: description length, weight_in_g is 40kg? for 1x1x1 meter?

# %% [markdown]
# #There was lot of not a number (NaN) data

# %%
seller_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
seller_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
seller_df.describe(include='all')
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %% [markdown]
# Error data should we clean is :
# <ul>
#     <l1>Order item: Type Data not match</l1>
#     <l1>Order DF item: Not A Number,Type Data not match</l1>
#     <l1>Product DF item: Not A Number,Description Info Error</l1>
# </ul>

# %% [markdown]
# <h2>Cleaning Data</h2>

# %%
# Cleaning the order items
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df['shipping_limit_date']=pd.to_datetime(order_items_df['shipping_limit_date'])
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# Cleaning the Order_df

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df[order_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
order_df[order_df.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
order_df[order_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
column=['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date']
for i in column:
    order_df[i]=pd.to_datetime(order_df[i])

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# Cleaning product_df

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_df.product_name_lenght.hist()
# Out:
# <AxesSubplot:>

# %%
product_df.product_name_lenght.fillna(value=product_df.product_name_lenght.mode(),inplace=True)
product_df.product_description_lenght.fillna(value=product_df.product_description_lenght.mean(),inplace=True)
product_df.product_name_lenght.fillna(value=product_df.product_name_lenght.mean(),inplace=True)
product_df.product_photos_qty.fillna(value=product_df.product_photos_qty.mean(),inplace=True)

# %%
product_df.product_category_name.fillna(value='cds_dvds_musicais',inplace=True)
product_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
product_df.product_weight_g.fillna(value=product_df.product_weight_g.mean(),inplace=True)
product_df.product_length_cm.fillna(value=product_df.product_length_cm.mean(),inplace=True)
product_df.product_height_cm.fillna(value=product_df.product_height_cm.mean(),inplace=True)
product_df.product_width_cm.fillna(value=product_df.product_width_cm.mean(),inplace=True)

# %%
product_df.isna().sum()
#Clear Data
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
#Cleaning ambigious weight?
product_df[product_df.product_weight_g==product_df.product_weight_g.max()]
# Out:
#                              product_id product_category_name  \
# 25166  26644690fde745fc4654719c3904e1db       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 25166                 59.0                       534.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 25166           40425.0               13.0               65.0
#
#        product_width_cm
# 25166              28.0

# %%
product_df.product_weight_g.replace(product_df.product_weight_g.max(), 1000, inplace=True)

# %%
product_df[product_df.product_weight_g==product_df.product_weight_g.max()]
# Out:
#                              product_id  \
# 344    d0877f0094337c414d23f5a3c7bad20c
# 509    53f92b0474f91fcb5bd188c6a8075c38
# 955    ceeba7d5636e59173cc5f484e913db3d
# 1159   f97ad9066c718a6cef93dfcf253d3e0d
# 1469   363a9f5b97bf194da23858be722a7aa5
# ...                                 ...
# 31654  3b85e44a54ca23950c469c7fb1cc0e0a
# 32179  d7f8b7443f6ae5796dabe493521a1e79
# 32262  ebf1c13032246ea801765e8cb5417365
# 32491  2b752ed328ea866e4721ca4e236a416c
# 32532  90c1b4e040d1d1c45897ec2dad4a809d
#
#                                 product_category_name  product_name_lenght  \
# 344                                 moveis_escritorio            48.000000
# 509                             utilidades_domesticas            54.000000
# 955                                 cds_dvds_musicais            48.476949
# 1159                                 moveis_decoracao            63.000000
# 1469                construcao_ferramentas_construcao            44.000000
# ...

# %%
english_product=pd.merge(left=product_df,right=product_category_df,how='inner',left_on="product_category_name",right_on="product_category_name")
english_product
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                 perfumaria
# 1      6a2fb4dd53d2cdb88e0432f1284a004c                 perfumaria
# 2      0d009643171aee696f4733340bc2fdd0                 perfumaria
# 3      b1eae565a61935e0011ee7682fef9dc9                 perfumaria
# 4      8da90b37f0fb171b4877c124f965b1f6                 perfumaria
# ...                                 ...                        ...
# 32933  c3d08bab8c7c6d9cc1f6cfb5a465c80b  moveis_colchao_e_estofado
# 32934  13b25797ad1e6d6c7cd3cbeb35f8ee7a  moveis_colchao_e_estofado
# 32935  dc36a7859b743d8610a2bbbaea26ece9  moveis_colchao_e_estofado
# 32936  107fde0930956120d1e13dd1062fbb46  moveis_colchao_e_estofado
# 32937  726b4e18f00255e2e63491bcba3f60b8  moveis_colchao_e_estofado
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# ...

# %%
english_product['product_category_name'] =english_product['product_category_name_english']

# %%
english_product
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                          perfumery
# 1      6a2fb4dd53d2cdb88e0432f1284a004c                          perfumery
# 2      0d009643171aee696f4733340bc2fdd0                          perfumery
# 3      b1eae565a61935e0011ee7682fef9dc9                          perfumery
# 4      8da90b37f0fb171b4877c124f965b1f6                          perfumery
# ...                                 ...                                ...
# 32933  c3d08bab8c7c6d9cc1f6cfb5a465c80b  furniture_mattress_and_upholstery
# 32934  13b25797ad1e6d6c7cd3cbeb35f8ee7a  furniture_mattress_and_upholstery
# 32935  dc36a7859b743d8610a2bbbaea26ece9  furniture_mattress_and_upholstery
# 32936  107fde0930956120d1e13dd1062fbb46  furniture_mattress_and_upholstery
# 32937  726b4e18f00255e2e63491bcba3f60b8  furniture_mattress_and_upholstery
#
# ...

# %%
seller_df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %% [markdown]
# <h2>Exploratory Data Analysis</h2>

# %%
#check relevance between customer and what his order

# %%
customer_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customer_order=pd.merge(left=customer_df,right=order_df,how="right",left_on="customer_id",right_on="customer_id")
customer_order
# Out:
#                             customer_id                customer_unique_id  \
# 0      9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1      b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 2      41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# 3      f88197465ea7920adcdbec7375364d82  7c142cf63193a1473d2e66489a9ae977
# 4      8ab97904e6daea8866dbdbc4fb7aad2c  72632f0f9dd73dfee390c9b22eb56dd6
# ...                                 ...                               ...
# 99436  39bd1228ee8140590ac3aca26f2dfe00  6359f309b166b0196dbf7ad2ac62bb5a
# 99437  1fca14ff2861355f6e5f14306ff977a7  da62f9e57a76d978d02ab5362c509660
# 99438  1aa71eb042121263aafbe80c1b562c9c  737520a9aad80b3fbbdad19b66b37b30
# 99439  b331b74b18dc79bcdf6532d51e1637c1  5097a5312c8b157bb7be58ae360ef43c
# 99440  edb027a75a1449115f6b43211ae02a24  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# ...

# %%
#Check which city has biggest order
customer_order.groupby(['customer_city','order_status']).agg({
    'customer_id':'nunique',
    'order_id':'nunique'
}).sort_values(by="customer_id",ascending=False)
# Out:
#                                customer_id  order_id
# customer_city    order_status
# sao paulo        delivered           15045     15045
# rio de janeiro   delivered            6601      6601
# belo horizonte   delivered            2697      2697
# brasilia         delivered            2071      2071
# curitiba         delivered            1489      1489
# ...                                    ...       ...
# macuco de minas  delivered               1         1
# carazinho        unavailable             1         1
# madalena         delivered               1         1
# presidente dutra canceled                1         1
# itaicaba         delivered               1         1
#
# [5310 rows x 2 columns]

# %%
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
product_item_df=pd.merge(left=order_items_df,right=english_product,how='left',left_on='product_id',right_on='product_id')

# %%
product_item_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
product_item_df.groupby(['product_category_name']).agg({
    'price':'sum',
    'freight_value':'sum'
}).sort_values(by='price',ascending=False)
# Out:
#                                 price  freight_value
# product_category_name
# health_beauty              1258681.34      182566.73
# watches_gifts              1205005.68      100535.93
# bed_bath_table             1036988.68      204693.04
# sports_leisure              988048.97      168607.51
# computers_accessories       911954.32      147318.08
# ...                               ...            ...
# diapers_and_hygiene           1567.59         573.68
# flowers                       1110.04         488.87
# home_comfort_2                 760.27         410.31
# fashion_childrens_clothes      569.85          95.51
# security_and_services          283.29          41.22
#
# [71 rows x 2 columns]

# %%
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
customer_order
# Out:
#                             customer_id                customer_unique_id  \
# 0      9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1      b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 2      41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# 3      f88197465ea7920adcdbec7375364d82  7c142cf63193a1473d2e66489a9ae977
# 4      8ab97904e6daea8866dbdbc4fb7aad2c  72632f0f9dd73dfee390c9b22eb56dd6
# ...                                 ...                               ...
# 99436  39bd1228ee8140590ac3aca26f2dfe00  6359f309b166b0196dbf7ad2ac62bb5a
# 99437  1fca14ff2861355f6e5f14306ff977a7  da62f9e57a76d978d02ab5362c509660
# 99438  1aa71eb042121263aafbe80c1b562c9c  737520a9aad80b3fbbdad19b66b37b30
# 99439  b331b74b18dc79bcdf6532d51e1637c1  5097a5312c8b157bb7be58ae360ef43c
# 99440  edb027a75a1449115f6b43211ae02a24  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# ...

# %%
customer_payment=pd.merge(left=customer_order,right=order_payments_df,how="left",left_on='order_id',right_on='order_id')

# %%
customer_payment
# Out:
#                              customer_id                customer_unique_id  \
# 0       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 2       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 3       b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 4       41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# ...                                  ...                               ...
# 103882  39bd1228ee8140590ac3aca26f2dfe00  6359f309b166b0196dbf7ad2ac62bb5a
# 103883  1fca14ff2861355f6e5f14306ff977a7  da62f9e57a76d978d02ab5362c509660
# 103884  1aa71eb042121263aafbe80c1b562c9c  737520a9aad80b3fbbdad19b66b37b30
# 103885  b331b74b18dc79bcdf6532d51e1637c1  5097a5312c8b157bb7be58ae360ef43c
# 103886  edb027a75a1449115f6b43211ae02a24  60350aa974b26ff12caad89e55993bd6
#
# ...

# %%
customer_card=customer_payment.groupby(by='payment_type').customer_id.nunique().sort_values(ascending=False).reset_index()

# %%
customer_card
# Out:
#   payment_type  customer_id
# 0  credit_card        76505
# 1       boleto        19784
# 2      voucher         3866
# 3   debit_card         1528
# 4  not_defined            3

# %%
customer_payment_card=customer_payment.groupby(['customer_city','payment_type']).agg({
    'customer_id':'nunique',
    'payment_value':'sum',
    
}).sort_values(by='customer_id',ascending=False)

# %%
customer_payment_card
# Out:
#                                   customer_id  payment_value
# customer_city       payment_type
# sao paulo           credit_card         12190     1757931.79
# rio de janeiro      credit_card          5512      942028.03
# sao paulo           boleto               2783      358042.07
# belo horizonte      credit_card          2227      343387.39
# brasilia            credit_card          1688      291241.56
# ...                                       ...            ...
# fonseca             credit_card             1         107.53
# florinia            credit_card             1          57.61
# piracuruca          boleto                  1         259.56
#                     credit_card             1          87.88
# abadia dos dourados boleto                  1          58.28
#
# [7499 rows x 2 columns]

# %%
order_payments_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
product_seller_df=pd.merge(left=product_item_df,right=seller_df,how="left",left_on='seller_id',right_on='seller_id')
product_seller_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
product_seller_df[product_seller_df.seller_city == '04482255']
# Out:
#                                order_id  order_item_id  \
# 96006  d9d6c371c6721e2fb73fc7ed7b5cc856              1
#
#                              product_id                         seller_id  \
# 96006  f1f41c991881dc3d4cbcedade3ec1622  ceb7b4fb9401cd378de7886317ad1b47
#
#       shipping_limit_date  price  freight_value product_category_name  \
# 96006 2017-09-08 18:08:20  399.9          16.55         health_beauty
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 96006                 39.0                      1949.0                 2.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 96006             750.0               22.0               23.0
#
#        product_width_cm product_category_name_english  seller_zip_code_prefix  \
# 96006              22.0                 health_beauty                   22790
#
#       seller_city seller_state
# 96006    04482255           RJ

# %%
product_seller_df[product_seller_df.seller_city=='04482255']=product_seller_df[product_seller_df.seller_city=='rio de janeiro']

# %%
product_seller_df.groupby(by=['seller_city','product_category_name']).agg({
    'seller_id':'nunique',
    'price':'sum'
}).sort_values(by='seller_id',ascending=False)
# Out:
#                                    seller_id      price
# seller_city product_category_name
# sao paulo   health_beauty                119  251521.79
#             sports_leisure               114  203593.68
#             housewares                   112  158139.02
#             furniture_decor               82  259877.64
#             auto                          81  100757.16
# ...                                      ...        ...
# ipira       small_appliances               1    1274.00
#             sports_leisure                 1      68.00
# ipua        pet_shop                       1     249.00
# irati       health_beauty                  1     447.00
# xaxim       stationery                     1     110.00
#
# [3306 rows x 2 columns]

# %%
all_df=pd.merge(left=customer_payment,right=product_seller_df,left_on='order_id',right_on='order_id')
all_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 2       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 3       b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 4       41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# ...                                  ...                               ...
# 117598  1fca14ff2861355f6e5f14306ff977a7  da62f9e57a76d978d02ab5362c509660
# 117599  1aa71eb042121263aafbe80c1b562c9c  737520a9aad80b3fbbdad19b66b37b30
# 117600  b331b74b18dc79bcdf6532d51e1637c1  5097a5312c8b157bb7be58ae360ef43c
# 117601  b331b74b18dc79bcdf6532d51e1637c1  5097a5312c8b157bb7be58ae360ef43c
# 117602  edb027a75a1449115f6b43211ae02a24  60350aa974b26ff12caad89e55993bd6
#
#         customer_zip_code_prefix customer_city customer_state  \
# ...

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117603 entries, 0 to 117602
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    117603 non-null  object
#  1   customer_unique_id             117603 non-null  object
#  2   customer_zip_code_prefix       117603 non-null  int64
#  3   customer_city                  117603 non-null  object
#  4   customer_state                 117603 non-null  object
#  5   order_id                       117603 non-null  object
#  6   order_status                   117603 non-null  object
#  7   order_purchase_timestamp       117603 non-null  datetime64[ns]
#  8   order_approved_at              117588 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   116359 non-null  datetime64[ns]
#  10  order_delivered_customer_date  115037 non-null  datetime64[ns]
# ...

# %% [markdown]
# Data Visualization

# %% [markdown]
# Searching the most customer payment

# %%
sns.barplot(y='customer_id',x='payment_type',data=customer_card)
plt.title('Number of Customer payment')
plt.xlabel(None)
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# Visualize the most product buy and the lowest product buy

# %%
product_price=product_item_df.groupby(['product_category_name']).agg({
    'price':'sum',
    'freight_value':'sum'
}).sort_values(by='price',ascending=False)

# %%
top_product=product_price.head().reset_index()

# %%
low_product=product_item_df.groupby(['product_category_name']).agg({
    'price':'sum',
    'freight_value':'sum'
}).sort_values(by='price',ascending=True)

# %%
low_product=low_product.head().reset_index()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(28, 10))
 
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x='price',y='product_category_name',data=top_product,ax=ax[0])
sns.barplot(x='price',y='product_category_name',data=low_product,ax=ax[1])
# Out:
# <AxesSubplot:xlabel='price', ylabel='product_category_name'>

# %% [markdown]
# Visualize the order timestamp from September 2016 to September 2018

# %%
monthly_order_df=all_df.resample(rule='M',on='order_purchase_timestamp').agg({
    'order_id':'nunique',
    'price':'sum'
})
monthly_order_df.index = monthly_order_df.index.strftime('%Y-%m')
monthly_order_df=monthly_order_df.reset_index()
monthly_order_df=monthly_order_df.rename(columns={
    'order_id':'order_purchase',
    'price':'revenue'
})

# %%
monthly_order_df
# Out:
#    order_purchase_timestamp  order_purchase     revenue
# 0                   2016-09               3      267.36
# 1                   2016-10             308    50942.23
# 2                   2016-11               0        0.00
# 3                   2016-12               1       10.90
# 4                   2017-01             789   128637.99
# 5                   2017-02            1733   260753.86
# 6                   2017-03            2641   396451.04
# 7                   2017-04            2391   391784.42
# 8                   2017-05            3660   545340.65
# 9                   2017-06            3217   453031.41
# 10                  2017-07            3969   533616.84
# 11                  2017-08            4292   601009.77
# 12                  2017-09            4243   662276.39
# 13                  2017-10            4568   693807.60
# 14                  2017-11            7451  1046127.84
# 15                  2017-12            5624   770656.15
# ...

# %%
plt.figure(figsize=(10, 5)) 
plt.plot(monthly_order_df["order_purchase_timestamp"], monthly_order_df["order_purchase"], marker='o', linewidth=2, color="#72BCD4") 
plt.title("Number of Orders per Month (2016-2018)", loc="center", fontsize=20) 
plt.xticks(fontsize=10,rotation=90) 
plt.yticks(fontsize=10,rotation=90) 
plt.show()

# %% [markdown]
# Visualize City has the biggest order

# %%
by_citydf=all_df.groupby(by='customer_city').customer_id.nunique().reset_index()
by_citydf.rename(columns={
    'customer_id':'customer_count'
},inplace=True)
by_citydf = by_citydf.sort_values(by='customer_count',ascending=False).head()

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count", 
    y="customer_city",
    data=by_citydf,
    palette=colors_
)
# Out:
# <AxesSubplot:xlabel='customer_count', ylabel='customer_city'>

# %% [markdown]
# Based on the question:
# 1. Health and Beauty has the most purchased product and Security and service has the lowest purchased product
# 2. Sao Paulo has the biggest order in Brazil
# 3. Most people use credit card for payment

# %% [markdown]
# Saving to .csv file

# %%
all_df.to_csv("all_data.csv", index=False)

# %%
all_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 2       9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 3       b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 4       41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# ...                                  ...                               ...
# 117598  1fca14ff2861355f6e5f14306ff977a7  da62f9e57a76d978d02ab5362c509660
# 117599  1aa71eb042121263aafbe80c1b562c9c  737520a9aad80b3fbbdad19b66b37b30
# 117600  b331b74b18dc79bcdf6532d51e1637c1  5097a5312c8b157bb7be58ae360ef43c
# 117601  b331b74b18dc79bcdf6532d51e1637c1  5097a5312c8b157bb7be58ae360ef43c
# 117602  edb027a75a1449115f6b43211ae02a24  60350aa974b26ff12caad89e55993bd6
#
#         customer_zip_code_prefix customer_city customer_state  \
# ...
